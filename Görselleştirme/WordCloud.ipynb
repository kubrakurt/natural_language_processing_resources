# %% [markdown]
# # WordCloud

# %%
import nltk
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from os import path
from PIL import Image
from textblob import Word
from nltk.corpus import stopwords
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

nltk.download("stopwords", quiet=True)
# Out:
# True

# %%
df = pd.read_csv("train.tsv", sep = "\t")

df["Phrase"] = df["Phrase"].apply(lambda x: " ".join(x.lower() for x in x.split()))
df["Phrase"] = df["Phrase"].str.replace("[^\w\s]", "")
df["Phrase"] = df["Phrase"].str.replace("\d", "")

sw = stopwords.words("english")

df["Phrase"] = df["Phrase"].apply(lambda x: " ".join(x for x in x.split() if x not in sw))
df.head()
# Out:
#    PhraseId  SentenceId                                             Phrase  \
# 0         1           1  series escapades demonstrating adage good goos...
# 1         2           1    series escapades demonstrating adage good goose
# 2         3           1                                             series
# 3         4           1
# 4         5           1                                             series
#
#    Sentiment
# 0          1
# 1          2
# 2          2
# 3          2
# 4          2

# %%
text = df["Phrase"][0]
text
# Out:
# 'series escapades demonstrating adage good goose also good gander occasionally amuses none amounts much story'

# %%
wordcloud = WordCloud().generate(text)
plt.imshow(wordcloud, interpolation = "bilinear")
plt.axis("off");

# %%
wordcloud = WordCloud(max_font_size = 50, max_words = 100, background_color = "white").generate(text)
plt.figure()
plt.imshow(wordcloud, interpolation = "bilinear")
plt.axis("off");

# %% [markdown]
# * Kelime bulutunu kaydetmek için:

# %%
wordcloud.to_file("kelime_bulutu.png");

# %% [markdown]
# * Tüm metin üzerinde:

# %%
text = " ".join(i for i in df["Phrase"])
wordcloud = WordCloud(max_font_size = 50, max_words = 100, background_color = "white").generate(text)
plt.figure(figsize = [10,10])
plt.imshow(wordcloud)
plt.axis("off");

# %% [markdown]
# * Şablonlara Göre WordCloud:

# %%
movie_mask = np.array(Image.open("şarap.jpg"))
movie_mask
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
wordcloud = WordCloud(max_words = 100, 
                      background_color = "white", 
                      mask = movie_mask, 
                      contour_width = 3, 
                      contour_color = "purple").generate(text)

plt.figure(figsize = [10,10])
plt.imshow(wordcloud, interpolation = "bilinear")
plt.axis("off");

# %%
movie_mask = np.array(Image.open("starbucks.jpg"))
movie_mask
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
wordcloud = WordCloud(max_words = 100, 
                      background_color = "white", 
                      mask = movie_mask, 
                      contour_width = 3).generate(text)

plt.figure(figsize = [10,10])
plt.imshow(wordcloud, interpolation = "bilinear")
plt.axis("off");

# %%
movie_mask = np.array(Image.open("tv.jpg"))
movie_mask
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[238, 238, 238],
#         [238, 238, 238],
#         [238, 238, 238],
#         ...,
#         [238, 238, 238],
#         [238, 238, 238],
#         [238, 238, 238]],
#
#        [[238, 238, 238],
#         [238, 238, 238],
#         [238, 238, 238],
#         ...,
#         [238, 238, 238],
#         [238, 238, 238],
#         [238, 238, 238]],
#
#        [[238, 238, 238],
#         [238, 238, 238],
#         [238, 238, 238],
# ...

# %%
wordcloud = WordCloud(max_words = 1000, 
                      background_color = "white", 
                      mask = movie_mask, 
                      contour_width = 3).generate(text)

plt.figure(figsize = [10,10])
plt.imshow(wordcloud, interpolation = "bilinear")
plt.axis("off");

# %%
movie_mask = np.array(Image.open("retro.png"))
movie_mask
# Out:
# array([[[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
# ...

# %%
wordcloud = WordCloud(max_words = 1000, 
                      background_color = "white", 
                      mask = movie_mask, 
                      contour_width = 3).generate(text)

plt.figure(figsize = [10,10])
plt.imshow(wordcloud, interpolation = "bilinear")
plt.axis("off");
